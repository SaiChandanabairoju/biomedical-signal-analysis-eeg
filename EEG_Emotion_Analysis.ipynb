# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.makedirs(
    "/content/drive/MyDrive/EEG_Project",
    exist_ok=True
)

print("EEG project folder created.")
# Out:
# EEG project folder created.

# %%
import zipfile
import os

zip_path = "/content/archive.zip"
extract_path = "/content/eeg_data"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Files extracted:")
print(os.listdir(extract_path))
# Out:
# Files extracted:
# ['emotions.csv']

# %%
import pandas as pd

file_path = "/content/eeg_data/emotions.csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
df.head()
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3       1.070       0.411
# 1       28.80      33.1      32.0      25.8      22.8       6.550       1.680
# 2        8.90      29.4    -416.0      16.7      23.7      79.900       3.360
# 3       14.90      31.6    -143.0      19.8      24.3      -0.584      -0.284
# 4       28.30      31.3      45.2      27.3      24.5      34.800      -5.790
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
# 3        8.82        2.30       -1.97  ...      299.0     -243.0     -243.0
# 4        3.06       41.40        5.52  ...       12.0       38.1       38.1
#
# ...

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 2132
# Columns: 2549

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2132 entries, 0 to 2131
# Columns: 2549 entries, # mean_0_a to label
# dtypes: float64(2548), object(1)
# memory usage: 41.5+ MB
# None

# %%
df.describe()
# Out:
#         # mean_0_a     mean_1_a     mean_2_a     mean_3_a     mean_4_a  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000
# mean     15.256914    27.012462  -104.975629    13.605898    24.150483
# std      15.284621     9.265141   206.271960    16.874676    14.187340
# min     -61.300000  -114.000000  -970.000000  -137.000000  -217.000000
# 25%       6.577500    26.075000  -195.000000     4.857500    23.600000
# 50%      14.100000    30.000000    14.950000    15.400000    25.200000
# 75%      27.700000    31.400000    29.600000    26.500000    26.800000
# max     304.000000    42.300000   661.000000   206.000000   213.000000
#
#         mean_d_0_a   mean_d_1_a   mean_d_2_a   mean_d_3_a   mean_d_4_a  ...  \
# count  2132.000000  2132.000000  2132.000000  2132.000000  2132.000000  ...
# mean      0.025378     0.052282     0.301655     0.036793     0.083567  ...
# std      17.981796     8.509174    68.098894    17.010031    18.935378  ...
# ...

# %%
print(df.columns.tolist())
# Out:
# ['# mean_0_a', 'mean_1_a', 'mean_2_a', 'mean_3_a', 'mean_4_a', 'mean_d_0_a', 'mean_d_1_a', 'mean_d_2_a', 'mean_d_3_a', 'mean_d_4_a', 'mean_d_0_a2', 'mean_d_1_a2', 'mean_d_2_a2', 'mean_d_3_a2', 'mean_d_4_a2', 'mean_d_5_a', 'mean_d_6_a', 'mean_d_7_a', 'mean_d_8_a', 'mean_d_9_a', 'mean_d_10_a', 'mean_d_11_a', 'mean_d_12_a', 'mean_d_13_a', 'mean_d_14_a', 'mean_d_15_a', 'mean_d_16_a', 'mean_d_17_a', 'mean_d_18_a', 'mean_d_19_a', 'mean_d_20_a', 'mean_d_21_a', 'mean_d_22_a', 'mean_d_23_a', 'mean_d_24_a', 'mean_d_25_a', 'mean_d_26_a', 'mean_d_27_a', 'mean_d_28_a', 'mean_d_29_a', 'mean_d_30_a', 'mean_d_31_a', 'mean_d_32_a', 'mean_d_33_a', 'mean_d_34_a', 'mean_d_35_a', 'mean_d_36_a', 'mean_d_37_a', 'mean_d_38_a', 'mean_d_39_a', 'mean_d_40_a', 'mean_d_41_a', 'mean_d_42_a', 'mean_d_43_a', 'mean_d_44_a', 'mean_d_45_a', 'mean_d_46_a', 'mean_d_47_a', 'mean_d_48_a', 'mean_d_49_a', 'stddev_0_a', 'stddev_1_a', 'stddev_2_a', 'stddev_3_a', 'stddev_4_a', 'stddev_d_0_a', 'stddev_d_1_a', 'stddev_d_2_a', 's
# ...

# %%
print(df["label"].value_counts())
# Out:
# label
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: count, dtype: int64

# %%
print(
    df["label"].value_counts(normalize=True) * 100
)
# Out:
# label
# NEUTRAL     33.583490
# NEGATIVE    33.208255
# POSITIVE    33.208255
# Name: proportion, dtype: float64

# %%
df[target].unique()
# Out:
# array(['NEGATIVE', 'NEUTRAL', 'POSITIVE'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))

sns.countplot(
    data=df,
    x="label"
)

plt.title("Emotion Class Distribution")
plt.xlabel("Emotion")
plt.ylabel("Number of Samples")

plt.show()

# %%
X = df.drop(columns=["label"])
y = df["label"]

# %%
print("Features:", X.shape)
print("Target:", y.shape)
# Out:
# Features: (2132, 2548)
# Target: (2132,)

# %%
X.dtypes.value_counts()
# Out:
# float64    2548
# Name: count, dtype: int64

# %%
non_numeric = X.select_dtypes(
    exclude="number"
).columns

print("Non-numeric columns:")
print(non_numeric.tolist())
# Out:
# Non-numeric columns:
# []

# %%
# 3. Missing Value Analysis

# %%
missing_count = df.isnull().sum()

print(
    missing_count[
        missing_count > 0
    ]
)
# Out:
# Series([], dtype: int64)

# %%
missing_percentage = (
    df.isnull().mean() * 100
)

missing_percentage = (
    missing_percentage[
        missing_percentage > 0
    ]
    .sort_values(ascending=False)
)

print(missing_percentage)
# Out:
# Series([], dtype: float64)

# %%
plt.figure(figsize=(15, 5))

sns.heatmap(
    df.isnull(),
    cbar=False,
    yticklabels=False
)

plt.title("Missing Data Pattern")

plt.show()

# %%
missing_summary = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percentage": df.isnull().mean() * 100
})

missing_summary = missing_summary.sort_values(
    "missing_percentage",
    ascending=False
)

missing_summary.head(20)
# Out:
#             missing_count  missing_percentage
# label                   0                 0.0
# # mean_0_a              0                 0.0
# mean_1_a                0                 0.0
# mean_2_a                0                 0.0
# mean_3_a                0                 0.0
# fft_734_b               0                 0.0
# fft_733_b               0                 0.0
# fft_732_b               0                 0.0
# fft_731_b               0                 0.0
# fft_730_b               0                 0.0
# fft_729_b               0                 0.0
# fft_728_b               0                 0.0
# fft_727_b               0                 0.0
# fft_726_b               0                 0.0
# fft_725_b               0                 0.0
# fft_724_b               0                 0.0
# fft_723_b               0                 0.0
# fft_722_b               0                 0.0
# fft_721_b               0                 0.0
# ...

# %%
X = X.fillna(X.median())

# %%
# 4. Duplicate Analysis
duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
X = df.drop(columns=["label"])
y = df["label"]

# %%
for prefix in ["mean", "mean_d", "fft"]:
    matching = [
        col for col in X.columns
        if col.startswith(prefix)
    ]

    print(prefix, ":", len(matching))
# Out:
# mean : 119
# mean_d : 110
# fft : 1500

# %%
print(
    [col for col in X.columns if col.startswith("mean")][:30]
)
# Out:
# ['mean_1_a', 'mean_2_a', 'mean_3_a', 'mean_4_a', 'mean_d_0_a', 'mean_d_1_a', 'mean_d_2_a', 'mean_d_3_a', 'mean_d_4_a', 'mean_d_0_a2', 'mean_d_1_a2', 'mean_d_2_a2', 'mean_d_3_a2', 'mean_d_4_a2', 'mean_d_5_a', 'mean_d_6_a', 'mean_d_7_a', 'mean_d_8_a', 'mean_d_9_a', 'mean_d_10_a', 'mean_d_11_a', 'mean_d_12_a', 'mean_d_13_a', 'mean_d_14_a', 'mean_d_15_a', 'mean_d_16_a', 'mean_d_17_a', 'mean_d_18_a', 'mean_d_19_a', 'mean_d_20_a']

# %%
print(
    [col for col in X.columns if col.startswith("fft")][:30]
)
# Out:
# ['fft_0_a', 'fft_1_a', 'fft_2_a', 'fft_3_a', 'fft_4_a', 'fft_5_a', 'fft_6_a', 'fft_7_a', 'fft_8_a', 'fft_9_a', 'fft_10_a', 'fft_11_a', 'fft_12_a', 'fft_13_a', 'fft_14_a', 'fft_15_a', 'fft_16_a', 'fft_17_a', 'fft_18_a', 'fft_19_a', 'fft_20_a', 'fft_21_a', 'fft_22_a', 'fft_23_a', 'fft_24_a', 'fft_25_a', 'fft_26_a', 'fft_27_a', 'fft_28_a', 'fft_29_a']

# %%
mean_features = [
    col for col in X.columns
    if col.startswith("mean")
]

fft_features = [
    col for col in X.columns
    if col.startswith("fft")
]

print("Mean features:", len(mean_features))
print("FFT features:", len(fft_features))
# Out:
# Mean features: 119
# FFT features: 1500

# %%
feature_group_summary = pd.DataFrame({
    "Feature Group": [
        "Mean-domain",
        "FFT/Frequency-domain"
    ],
    "Number of Features": [
        len(mean_features),
        len(fft_features)
    ]
})

feature_group_summary
# Out:
#           Feature Group  Number of Features
# 0           Mean-domain                 119
# 1  FFT/Frequency-domain                1500

# %%
X.describe().T
# Out:
#              count        mean         std     min       25%    50%      75%  \
# # mean_0_a  2132.0   15.256914   15.284621   -61.3    6.5775  14.10   27.700
# mean_1_a    2132.0   27.012462    9.265141  -114.0   26.0750  30.00   31.400
# mean_2_a    2132.0 -104.975629  206.271960  -970.0 -195.0000  14.95   29.600
# mean_3_a    2132.0   13.605898   16.874676  -137.0    4.8575  15.40   26.500
# mean_4_a    2132.0   24.150483   14.187340  -217.0   23.6000  25.20   26.800
# ...            ...         ...         ...     ...       ...    ...      ...
# fft_745_b   2132.0   -6.934144  281.040552 -1160.0 -102.5000  89.70  153.000
# fft_746_b   2132.0   95.104886  203.194976 -1010.0   -8.8375  13.40  149.250
# fft_747_b   2132.0  -49.061255  106.486317  -521.0  -87.1500 -24.10   10.925
# fft_748_b   2132.0  -49.061255  106.486317  -521.0  -87.1500 -24.10   10.925
# fft_749_b   2132.0   95.104886  203.194976 -1010.0   -8.8375  13.40  149.250
#
#                max
# # mean_0_a   304.0
# ...

# %%
statistics = X.describe().T

statistics.to_csv(
    "/content/feature_statistics.csv"
)

# %%
std_summary = X.std().sort_values()

std_summary.head(20)
# Out:
# entropy4_b    0.262643
# entropy4_a    0.283811
# logm_38_b     0.684752
# logm_38_a     0.685360
# logm_47_b     0.847731
# logm_47_a     0.848544
# logm_20_a     0.904958
# logm_20_b     0.905102
# logm_46_a     1.111319
# logm_46_b     1.113929
# logm_43_b     1.173955
# logm_43_a     1.175898
# logm_60_a     1.212143
# logm_16_b     1.213348
# logm_60_b     1.213491
# logm_16_a     1.214205
# logm_30_a     1.221812
# logm_30_b     1.222084
# logm_39_a     1.258932
# logm_39_b     1.260134
# dtype: float64

# %%
std_summary.tail(20)
# Out:
# moments_11_b    3.297504e+11
# moments_11_a    3.297504e+11
# moments_13_a    4.747135e+11
# moments_13_b    4.747137e+11
# moments_14_a    1.677387e+12
# moments_14_b    1.677387e+12
# moments_10_a    2.302801e+12
# moments_10_b    2.302801e+12
# moments_12_a    5.068557e+13
# moments_12_b    5.068566e+13
# moments_16_a    2.468296e+14
# moments_16_b    2.468296e+14
# moments_18_b    7.165183e+14
# moments_18_a    7.165183e+14
# moments_19_a    2.053021e+15
# moments_19_b    2.053021e+15
# moments_15_b    5.781922e+15
# moments_15_a    5.781922e+15
# moments_17_b    7.938976e+16
# moments_17_a    7.938985e+16
# dtype: float64

# %%
sample_features = X.columns[:10]

plt.figure(figsize=(15, 7))

sns.boxplot(
    data=X[sample_features]
)

plt.xticks(rotation=45)

plt.title("Distribution of Selected EEG Features")

plt.show()

# %%
def count_iqr_outliers(series):

    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return (
        (series < lower) |
        (series > upper)
    ).sum()

# %%
outlier_counts = {}

for col in X.columns:

    outlier_counts[col] = count_iqr_outliers(
        X[col]
    )

outlier_counts = pd.Series(
    outlier_counts
).sort_values(
    ascending=False
)

outlier_counts.head(20)
# Out:
# moments_12_b    1003
# moments_12_a    1003
# moments_2_b      946
# moments_2_a      944
# covmat_7_b       802
# covmat_7_a       802
# covmat_84_a      802
# covmat_84_b      802
# moments_13_b     791
# moments_13_a     790
# covmat_106_b     778
# covmat_128_b     778
# covmat_128_a     777
# covmat_106_a     777
# covmat_140_b     765
# covmat_107_b     765
# covmat_140_a     761
# covmat_107_a     761
# moments_3_b      755
# moments_3_a      753
# dtype: int64

# %%
feature = X.columns[0]

plt.figure(figsize=(10, 5))

sns.histplot(
    X[feature],
    kde=True
)

plt.title(
    f"Distribution of {feature}"
)

plt.show()

# %%
selected_features = X.columns[:6]

for feature in selected_features:

    plt.figure(figsize=(8, 4))

    sns.histplot(
        X[feature],
        kde=True
    )

    plt.title(
        f"Distribution of {feature}"
    )

    plt.show()

# %%
eda_df = df[
    ["label"] + list(X.columns[:10])
]

# %%
feature = X.columns[0]

plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="label",
    y=feature
)

plt.title(
    f"{feature} Across Emotion Classes"
)

plt.show()

# %%
selected_features = X.columns[:20]

corr = X[selected_features].corr()

# %%
plt.figure(figsize=(14, 10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0
)

plt.title(
    "Correlation Heatmap of Selected EEG Features"
)

plt.show()

# %%
import numpy as np
corr_matrix = X.corr().abs()

upper = corr_matrix.where(
    np.triu(
        np.ones(corr_matrix.shape),
        k=1
    ).astype(bool)
)

high_corr = [
    column
    for column in upper.columns
    if any(
        upper[column] > 0.95
    )
]

print(
    "Highly correlated features:",
    len(high_corr)
)
# Out:
# Highly correlated features: 1257

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(
    n_components=2
)

X_pca = pca.fit_transform(
    X_scaled
)

# %%
pca_df = pd.DataFrame(
    X_pca,
    columns=["PC1", "PC2"]
)

pca_df["label"] = y.values

# %%
plt.figure(figsize=(10, 7))

sns.scatterplot(
    data=pca_df,
    x="PC1",
    y="PC2",
    hue="label"
)

plt.title(
    "PCA Projection of EEG Features"
)

plt.show()

# %%
print(
    "PC1:",
    pca.explained_variance_ratio_[0]
)

print(
    "PC2:",
    pca.explained_variance_ratio_[1]
)
# Out:
# PC1: 0.3677256411753876
# PC2: 0.09553894257232612

# %%
cleaned_df = df.copy()

cleaned_df.to_csv(
    "/content/eeg_cleaned.csv",
    index=False
)

print("Saved successfully.")
# Out:
# Saved successfully.

# %%
from google.colab import files

files.download(
    "/content/eeg_cleaned.csv"
)

# %%
import os

os.makedirs(
    "/content/results/figures",
    exist_ok=True
)

# %%
plt.savefig(
    "/content/results/figures/emotion_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

# %%
requirements = """pandas
numpy
matplotlib
seaborn
scipy
scikit-learn
jupyter
"""

with open(
    "/content/requirements.txt",
    "w"
) as f:
    f.write(requirements)

# %%
files.download("/content/requirements.txt")

# %%
files.download("/content/eeg_cleaned.csv")
